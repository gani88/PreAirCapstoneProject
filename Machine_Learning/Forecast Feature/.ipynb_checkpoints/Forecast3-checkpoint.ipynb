# %%
# Forecasting for PM10 and CO in AQI

# %%
# Libraries
import pandas as pd
import pandas as pandasForSortingCSV
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout

import math
import glob
import os

plt.style.use('fivethirtyeight')

# %%
# Upload Dataset and Sort
df = pd.read_csv(r'C:\Users\zarek\Capstone\Dataset\ispu_data.csv', index_col=False)
df.head(10)
# Out:
#       tanggal  pm10 so2  co   o3  no2  max critical     categori lokasi_spku
# 0  2019-01-01    29  15   7   71   13   71       O3       SEDANG        DKI2
# 1  2019-01-02    24  17   6   79    6   79       O3       SEDANG        DKI2
# 2  2019-01-03    23  16   6   65    4   65       O3       SEDANG        DKI2
# 3  2019-01-04    42  18  10   64   11   64       O3       SEDANG        DKI2
# 4  2019-01-05    54  29  16   51   20   54     PM10       SEDANG        DKI3
# 5  2019-01-06    69  34  30  105   27  105       O3  TIDAK SEHAT        DKI2
# 6  2019-01-07    71  47  16  132   25  132       O3  TIDAK SEHAT        DKI3
# 7  2019-01-08    51  22  25  143   26  143       O3  TIDAK SEHAT        DKI3
# 8  2019-01-09    61  22  28  198   21  198       O3  TIDAK SEHAT        DKI1
# 9  2019-01-10    59  22  27  128   18  128       O3  TIDAK SEHAT        DKI1

# %%
df.shape
# Out:
# (1076, 10)

# %%
# PM10 Graph
plt.figure(figsize=(12,8))
plt.title("PM10")
plt.plot(df['pm10'])
plt.xlabel('tanggal', fontsize=18)
plt.ylabel('Tingkat PM10', fontsize=18)
plt.show()

# %%
# Only PM10 Dataframe
data = df.filter(['pm10'])
dataset = data.values

#Train Data
training_data_len = math.ceil(len(dataset) * .8)

training_data_len
# Out:
# 861

# %%
 #Data Scalling
scale = MinMaxScaler(feature_range=(0,1))
scaled_data = scale.fit_transform(dataset)

scaled_data
# Out:
# array([[0.16201117],
#        [0.13407821],
#        [0.12849162],
#        ...,
#        [0.34078212],
#        [0.33519553],
#        [0.3575419 ]])

# %%
#Build Training Dataset

train_data = scaled_data[0:training_data_len , :]

#Split train data
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i <= 60:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.16201117, 0.13407821, 0.12849162, 0.23463687, 0.30167598,
#        0.38547486, 0.39664804, 0.2849162 , 0.34078212, 0.32960894,
#        0.35195531, 0.31843575, 0.36312849, 0.36312849, 0.40223464,
#        0.20670391, 0.31284916, 0.15083799, 0.24581006, 0.41340782,
#        0.34636872, 0.21787709, 0.32960894, 0.2849162 , 0.17877095,
#        0.35195531, 0.31284916, 0.29608939, 0.26815642, 0.26256983,
#        0.31284916, 0.34078212, 0.34078212, 0.3575419 , 0.31284916,
#        0.31843575, 0.29050279, 0.39106145, 0.35195531, 0.32960894,
#        0.32960894, 0.20670391, 0.31284916, 0.37430168, 0.40782123,
#        0.30167598, 0.23463687, 0.30726257, 0.2849162 , 0.40223464,
#        0.38547486, 0.38547486, 0.33519553, 0.23463687, 0.31843575,
#        0.32960894, 0.34078212, 0.3575419 , 0.31284916, 0.32402235])]
# [0.27932960893854747]

# %%
# Convert x_train, y_train to numpy

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshape Data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (801, 60, 1)

# %%
# LSTM Model
model = Sequential()
model.add(LSTM(30, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(250, return_sequences=False))
model.add(Dense(256))
model.add(Activation("relu"))
model.add(Dense(1))

# model = tf.keras.models.Sequential([
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
#     tf.keras.layers.Dense(1),
# ])

# %%
# Compile Model

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])

# %%
# Summary
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 60, 30)            3840
#
#  lstm_17 (LSTM)              (None, 250)               281000
#
#  dense_13 (Dense)            (None, 256)               64256
#
#  activation (Activation)     (None, 256)               0
#
#  dense_14 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 349,353
# Trainable params: 349,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training Model
model.fit(x_train, y_train, batch_size=64, epochs=30)
# Out:
# Epoch 1/30
# 13/13 [==============================] - 66s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 2/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 3/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 4/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 5/30
# 13/13 [==============================] - 62s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 6/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 7/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 8/30
# 13/13 [==============================] - 65s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 9/30
# 13/13 [==============================] - 64s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 10/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 11/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 12/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 13/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 14/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 15/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 16/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 17/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 18/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 19/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 20/30
# 13/13 [==============================] - 62s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 21/30
# 13/13 [==============================] - 64s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 22/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 23/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 24/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 25/30
# 13/13 [==============================] - 64s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 26/30
# 13/13 [==============================] - 64s 5s/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 27/30
# 13/13 [==============================] - 62s 5s/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 28/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 29/30
# 13/13 [==============================] - 62s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 30/30
# 13/13 [==============================] - 63s 5s/step - loss: 0.0045 - mean_squared_error: 0.0045

# %%
# Build Testing Dataset
# Dataset containing the remainder of training_data_len
test_data = scaled_data[training_data_len - 60: , :]

# Dataset x_test, y_test
x_test = []
y_test = dataset[training_data_len:, :]

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
#Convert Data to numpy (test)
x_test = np.array(x_test)

# %%
#Reshape test data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
#Trying Predict Value
pred = model.predict(x_test)
pred = scale.inverse_transform(pred)
# Out:
# 7/7 [==============================] - 12s 1s/step

# %%
# Evaluate the Model use root mean squared error RMSE
rmse = np.sqrt(np.mean(pred - y_test) ** 2)
rmse
# Out:
# 1.6151510016862736

# %%
#Plot Data
train = data[:training_data_len]
validation = data[training_data_len:]
validation['Predictions'] = pred

# Graph the Plot
plt.figure(figsize=(12,8))
plt.title('Model')
plt.xlabel('Tanggal', fontsize=18)
plt.ylabel('Tingkat PM10', fontsize=18)
plt.plot(train['pm10'])
plt.plot(validation[['pm10', 'Predictions']])
plt.legend(['Train', 'Val', 'Prediction'], loc='lower right')
plt.show()
# Out:
# C:\Users\zarek\AppData\Local\Temp\ipykernel_2008\1435648989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation['Predictions'] = pred

# %%
validation
# Out:
#       pm10  Predictions
# 861     62    61.023495
# 862     73    60.506630
# 863     68    61.162682
# 864     68    61.879570
# 865     66    62.559750
# ...    ...          ...
# 1071    75    55.960785
# 1072    59    56.745106
# 1073    61    57.236534
# 1074    60    57.732399
# 1075    64    58.089222
#
# [215 rows x 2 columns]
